# %% [markdown]
# # Andre - MinHashing - Horoscope_general

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## test Data

# %%
sentence = "As the evening sun dipped gently beneath the horizon, casting"

#"As the evening sun dipped gently beneath the horizon, casting a golden glow across the rippling fields and the distant, silent woods, I wandered along the winding path, listening to the cheerful chorus of birds, feeling the cool breeze against my face, and reflecting on the tranquil beauty of the world, grateful for the peace and quiet that embraced me in that fleeting, perfect moment of serenity at the close of the day."

# %%
sentence_splitted = sentence.split()
rewriten_random_sentence = []
list_indexes = list(range(len(sentence_splitted)))

for word in sentence_splitted:
    random_index = np.random.choice(list_indexes)
    list_indexes.remove(random_index)
    rewriten_random_sentence.append(sentence_splitted[random_index])
    joined_rewriten_random_sentence = ' '.join(rewriten_random_sentence)

# %%
def random_sentence_rewriter(sentence):
    sentence_splitted = sentence.split()
    rewriten_random_sentence = []
    list_indexes = list(range(len(sentence_splitted)))
    for word in sentence_splitted:
        random_index = np.random.choice(list_indexes)
        list_indexes.remove(random_index)
        rewriten_random_sentence.append(sentence_splitted[random_index])
    
    joined_rewriten_random_sentence = ' '.join(rewriten_random_sentence)
    return joined_rewriten_random_sentence

# %%
i=random_sentence_rewriter(sentence)
i
# Out:
# 'casting As horizon, the sun the evening gently beneath dipped'

# %%
size=10
test_df = pd.DataFrame({
    "ID" : range(1, size+1),
    "category": ['general'] * (size),
    'horoscope': [sentence] * (size)
})

test_df
# Out:
#    ID category                                          horoscope
# 0   1  general  As the evening sun dipped gently beneath the h...
# 1   2  general  As the evening sun dipped gently beneath the h...
# 2   3  general  As the evening sun dipped gently beneath the h...
# 3   4  general  As the evening sun dipped gently beneath the h...
# 4   5  general  As the evening sun dipped gently beneath the h...
# 5   6  general  As the evening sun dipped gently beneath the h...
# 6   7  general  As the evening sun dipped gently beneath the h...
# 7   8  general  As the evening sun dipped gently beneath the h...
# 8   9  general  As the evening sun dipped gently beneath the h...
# 9  10  general  As the evening sun dipped gently beneath the h...

# %%
for index in range(size-2):
    test_df.at[index+1, 'horoscope'] = random_sentence_rewriter(sentence)
test_df
# Out:
#    ID category                                          horoscope
# 0   1  general  As the evening sun dipped gently beneath the h...
# 1   2  general  horizon, As the beneath the sun dipped gently ...
# 2   3  general  the beneath casting sun dipped As the evening ...
# 3   4  general  horizon, sun beneath the evening dipped As the...
# 4   5  general  gently the casting the sun evening beneath As ...
# 5   6  general  gently casting horizon, beneath sun the evenin...
# 6   7  general  dipped beneath casting gently As the horizon, ...
# 7   8  general  As beneath evening casting horizon, gently the...
# 8   9  general  As sun the horizon, the gently casting dipped ...
# 9  10  general  As the evening sun dipped gently beneath the h...

# %% [markdown]
# # Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

subset = "horoscope_full"
df = pd.read_csv('../data/horoscope_full.csv')
df= df

# %%
df
# Out:
#           ID    sign  category      date  \
# 0          1   aries   general  20200617
# 1          2   aries   general  20200618
# 2          3   aries   general  20200619
# 3          4   aries   general  20200620
# 4          5   aries   general  20200621
# ...      ...     ...       ...       ...
# 21954  21955  pisces  birthday  20210612
# 21955  21956  pisces  birthday  20210613
# 21956  21957  pisces  birthday  20210614
# 21957  21958  pisces  birthday  20210615
# 21958  21959  pisces  birthday  20210616
#
#                                                horoscope
# 0      There's a great day ahead of you, Aries. You'l...
# 1      People will understand and appreciate your des...
# 2      You are very interested in technological break...
# 3      Stress from overwork could have you feeling we...
# 4      This is a good day to stand up for yourself an...
# ...                                                  ...
# 21954  Celebrate in style on your birthday in prepara...
# 21955  Imagine your life as if it was exactly the way...
# 21956  Fun, playfulness, and humor are easy to manife...
# 21957  Your birthday brings you a fresh start, as you...
# 21958  You will probably enjoy being the center of at...
#
# [21959 rows x 5 columns]

# %%
df_general = df[df["category"] == "general"]

horoscope_general_dict = {
    row["ID"]: row["horoscope"]
    for _, row in df_general.iterrows()
}

# %%
df[df['category'] == "general"]
# Out:
#           ID    sign category      date  \
# 0          1   aries  general  20200617
# 1          2   aries  general  20200618
# 2          3   aries  general  20200619
# 3          4   aries  general  20200620
# 4          5   aries  general  20200621
# ...      ...     ...      ...       ...
# 20490  20491  pisces  general  20210612
# 20491  20492  pisces  general  20210613
# 20492  20493  pisces  general  20210614
# 20493  20494  pisces  general  20210615
# 20494  20495  pisces  general  20210616
#
#                                                horoscope
# 0      There's a great day ahead of you, Aries. You'l...
# 1      People will understand and appreciate your des...
# 2      You are very interested in technological break...
# 3      Stress from overwork could have you feeling we...
# 4      This is a good day to stand up for yourself an...
# ...                                                  ...
# 20490  You may be shy when it comes to expressing you...
# 20491  When did you last spend real quality time with...
# 20492  Your self-confidence will get you out of any s...
# 20493  You're in splendid shape today, Pisces! Did a ...
# 20494  Your actions might be a bit strained today, Pi...
#
# [4391 rows x 5 columns]

# %%
len(horoscope_general_dict)
# Out:
# 4391

# %% [markdown]
# # Funtions

# %%
import random
import re

def normalize_text(text):
    text = text.lower()
    
    # 1. Remove punctuation and replace with a space
    text = re.sub(r"[^\w\s]", " ", text) # Removes everything that is not a word character or whitespace
    
    # 2. Remove multiple spaces
    text = re.sub(r"\s+", " ", text).strip()
    
    # 3. Return the list of words (tokens)
    return text.split(' ')


def shingle(q, text):
    newtext = normalize_text(text)
    shingles = []
    # The index must go from 0 to the last shingle index. 
    # The last shingle index is N (number of words) - q. 
    # We add +1 so it's not excluded by the Python for loop's range.
    for i in range(len(newtext) - q + 1): 
        # The join method combines elements of a list into a single string, 
        # separated by a space character (" "). In this case, 
        # the list elements go from index i to index i+q.
        shingles.append(" ".join(newtext[i:i + q])) 
    
    # Remove repetitions
    unique = set(shingles) 
    # Convert back to a list
    list_shingles = list(unique) 
    
    return list_shingles

# %%
import sys
import os
import mmh3


#################### Utilities ######################
#hashes a list of strings
def listhash(l,seed):
	val = 0
	for e in l:
		val = val ^ mmh3.hash(e, seed)
	return val

# %%
def signature(docs: dict, seedlist: list, q: int):
    
    
    doc_ids = list(docs.keys()) #estraggo id del dizionario dall dict, ora ho una lista con ID del dizionario
    k = len(seedlist) # k è il numero di funzioni hash
    
    
    shingle_to_docs = {} #preparo un dict vuoto
    
    # Ciclo iniziale per popolare l'indice e preparare gli shingles
    for doc_id, text in docs.items(): #associo in doc_id ID dei documenti e in text il testo dei documenti
        
        shingles_list = shingle(q, text) #preparo la lista di shingles, questo per un documento 
        for shingle_item in shingles_list:
          
            shingle_to_docs.setdefault(shingle_item, set()).add(doc_id)

        # il doppio ciclo mi serve per scorrere tutti i documenti e in ogni documento ogni shingle
        # ho la mia lista vuota a cui applico la funzione setdefault questa funzione prende la key (uno shingle) 
        # e la cerca all'interno del dizionario se c'è aggiunge un altro documento ID nella raccolta set dei value, 
        # se non c'è crea questa chiave e aggiunge L'ID del documento immediatamente all'interno di un oggetto set  
        # quello che ho alla fine è un grande dictionary con tutti gli shingles come key e i documenti dove sono presenti come value
         

    doc_signatures = {              #definisco il dizionario delle firme con id come key e una lista lunga quanto le funzioni hash con all'interno solo inf, quindi k inf
        doc_id: [float("inf")] * k  #[float("inf")] * k  quando moltiplichi una lista contenente un singolo elemento per un numero intero, il risultato 
                                    #è una nuova lista in cui quell'elemento è ripetuto k volte.
        for doc_id in doc_ids
    } # quindi ora ho un dict inizializzato con le key dei documenti e come value una lista lunga quanto il numero di f.ash di infinito
    
    # a questo punto ho un dict che ha come key gli shingles e come value la lista dove lo shingle si trova shingle_to_docs 
    # inoltre ho un dict doc_signatures che ha come key gli id dei documenti e come value invece una lista di infiniti tanti quante le funzioni hash 
    
    for shingle_item in shingle_to_docs.keys(): # prendi lo shingle (key) dalla lista di shingle (ciclato su tutti gli shingle)
        
        hash_values = [listhash(shingle_item, seed) for seed in seedlist] # prendo lo shingle e gli applico tutte l hash function e le salvo in una lista
        
        for doc_id in shingle_to_docs[shingle_item]: #scorri tutti gli ID dove trovi questo shingle. shingle_to_docs[shingle_item] è il value ovvero la lista ID dove puoi
                                                     #trovare lo shingle e scorri tutti gli ID
            current_signature = doc_signatures[doc_id]# la firma corrente è la prima volta tutti infiniti e poi si aggiorna con tutti i minimi
            for i in range(k):
                current_signature[i] = min(current_signature[i], hash_values[i])
                
    #prendo lo shingle e gli applico tutte le funzioni hash e le salvo in una lista che avrà lunghezza k
    #prendo la lista dei documenti dove questo shingle è presente
    # per ogni documento in cui è presente cerco la sua firma attuale
    # controllo funzione per funzione se l'ash che ho adesso è minore nel caso sostiuisco
    # quindi per ogni shingles, per ogni documento in cui è contenuto e per ogni funzione ash.            
    return doc_signatures

# %%
import numpy as np
def jaccard (doc_id_1: str, doc_id_2: str, doc_signatures: dict):
    sign1 = np.array(doc_signatures[doc_id_1])
    sign2 = np.array(doc_signatures[doc_id_2])
    matches = 0
    k = len(sign1)
    
    for i in range(k):
        if sign1[i] == sign2[i]:
            matches += 1
            
    similarity = matches / k
    return similarity

# %%
def similar(doc_signatures, threshold):
    list_keys = list(doc_signatures.keys()) # I save all the keys of the documents in a list
    similar_items = {} # empty dict to save the two ids and the similarity value
    
    # double for cycle with i less than j so as not to repeat the combinations
    for i in range (len(list_keys)-1): 
        for j in range (i + 1, len(list_keys)):
            similarity_score = jaccard(list_keys[i], list_keys[j], doc_signatures)
            if similarity_score >= threshold:
                # as key I put the two IDs of the documents, as value the similarity value
                similar_items[(list_keys[i], list_keys[j])] = similarity_score 
                
    return similar_items

# %%
def lsh(signatures_dict, b, jaccard_threshold=0.5, seed=42):
    lsh_dict = {} # new dict that has as key the IDs and as value the hashes of the blocks
    for key, values in signatures_dict.items(): # for each item with its key value ID: signature
        blocks = np.split(np.array(values), b) # split the signature into blocks
        blocks_hash_values = [] # empty list for the new signature
        for aBlock in blocks: # for each block among the blocks
            band_bytes = aBlock.tobytes()
            # hash for each block until a list of hashes is created
            blocks_hash_values.append(mmh3.hash(band_bytes, seed)) 
        # in the dict I put the ID in the key and the new list of hashed blocks in the value
        lsh_dict[key] = blocks_hash_values 
        
    list_keys = list(lsh_dict.keys()) # I save the list of keys
    similar_items = {} # new dict
    
    for i in range (len(list_keys)-1):
        for j in range (i+1, len(list_keys)):
            # how many in common in the new list?
            common_values = np.intersect1d(lsh_dict[list_keys[i]], lsh_dict[list_keys[j]]) 
            
            # if at least one then they are candidates and I calculate them with jaccard
            if len(common_values) > 0: 
                # we found a candidate
                similarity_score = jaccard(list_keys[i], list_keys[j], signatures_dict)
                
                # if they exceed the threshold
                if similarity_score >= jaccard_threshold: 
                    # the key of similar items are the name of the two documents and the value is the similarity
                    similar_items[(list_keys[i], list_keys[j])] = similarity_score 

            if len(common_values) == 0:
                similar_items[(list_keys[i], list_keys[j])] = 0.0
                    
    return similar_items

# %% [markdown]
# # Run Code

# %% [markdown]
# ## size of shingles = 1

# %%
# Parameters

q = 1   # size of the shingle (in words)                   
                            
r = 3      # rows per band                   
                           
k = 120                     # number of hash functions
                            
b = k // r                  # number of bands 
                            
threshold = 0            # minimum similarity threshold 
                            
seedlist = list(range(k))   # list of seeds for the hash functions 
                            
seed_lsh = 42               # seed for hashing the blocks 
                            
# Compute MinHash signatures on all documents
full_signatures = signature(horoscope_general_dict, seedlist, q)
print("Signatures computed.")

# Find similar items using the LSH function

similar_items_lsh = lsh(full_signatures, b, jaccard_threshold=threshold, seed=seed_lsh)
# Out:
# Signatures computed.

# %%
similar_items_lsh_highest_value = max(similar_items_lsh.items(), key=lambda x: x[1])
print("Highest similarity pair:")
print(f"ID1: {similar_items_lsh_highest_value[0][0]}, ID2: {similar_items_lsh_highest_value[0][1]}, Similarità: {similar_items_lsh_highest_value[1]:.2f}")
print(f"Text1: {horoscope_general_dict[similar_items_lsh_highest_value[0][0]]}")
print(f"Text2: {horoscope_general_dict[similar_items_lsh_highest_value[0][1]]}")
# Out:
# Highest similarity pair:
# ID1: 11100, ID2: 11147, Similarità: 1.00
# Text1: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.
# Text2: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.

# %%
similar_items_lsh_q_1 = similar_items_lsh

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# First histogram: regular y-scale
ax[0].hist(similar_items_lsh_q_1.values(), bins=100, edgecolor='black')
ax[0].set_title('Histogram of Similarity Scores (Shingle Size = 1)')
ax[0].set_xlabel('Similarity Score')
ax[0].set_ylabel('Frequency')

# Second histogram: log y-scale
ax[1].hist(similar_items_lsh_q_1.values(), bins=100, edgecolor='black')
ax[1].set_title('Histogram of Similarity Scores (Shingle Size = 1)')
ax[1].set_xlabel('Similarity Score')
ax[1].set_ylabel('Log(Frequency)')
ax[1].set_yscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## size of shingles = 2

# %%
# Parameters

q = 2   # size of the shingle (in words)                   
                            
r = 3      # rows per band                   
                           
k = 120                     # number of hash functions
                            
b = k // r                  # number of bands 
                            
threshold = 0            # minimum similarity threshold 
                            
seedlist = list(range(k))   # list of seeds for the hash functions 
                            
seed_lsh = 42               # seed for hashing the blocks 
                            
# Compute MinHash signatures on all documents
full_signatures = signature(horoscope_general_dict, seedlist, q)
print("Signatures computed.")

# Find similar items using the LSH function

similar_items_lsh = lsh(full_signatures, b, jaccard_threshold=threshold, seed=seed_lsh)
# Out:
# Signatures computed.

# %%
similar_items_lsh_highest_value = max(similar_items_lsh.items(), key=lambda x: x[1])
print("Highest similarity pair:")
print(f"ID1: {similar_items_lsh_highest_value[0][0]}, ID2: {similar_items_lsh_highest_value[0][1]}, Similarità: {similar_items_lsh_highest_value[1]:.2f}")
print(f"Text1: {horoscope_general_dict[similar_items_lsh_highest_value[0][0]]}")
print(f"Text2: {horoscope_general_dict[similar_items_lsh_highest_value[0][1]]}")
# Out:
# Highest similarity pair:
# ID1: 11100, ID2: 11147, Similarità: 1.00
# Text1: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.
# Text2: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.

# %%
similar_items_lsh_q_2 = similar_items_lsh

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# First histogram: regular y-scale
ax[0].hist(similar_items_lsh_q_2.values(), bins=100, edgecolor='black')
ax[0].set_title('Histogram of Similarity Scores (Shingle Size = 2)')
ax[0].set_xlabel('Similarity Score')
ax[0].set_ylabel('Frequency')

# Second histogram: log y-scale
ax[1].hist(similar_items_lsh_q_2.values(), bins=100, edgecolor='black')
ax[1].set_title('Histogram of Similarity Scores (Shingle Size = 2)')
ax[1].set_xlabel('Similarity Score')
ax[1].set_ylabel('Log(Frequency)')
ax[1].set_yscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## size of shingles = 3

# %%
# Parameters

q = 3   # size of the shingle (in words)                   
                            
r = 3      # rows per band                   
                           
k = 120                     # number of hash functions
                            
b = k // r                  # number of bands 
                            
threshold = 0            # minimum similarity threshold 
                            
seedlist = list(range(k))   # list of seeds for the hash functions 
                            
seed_lsh = 42               # seed for hashing the blocks 
                            
# Compute MinHash signatures on all documents
full_signatures = signature(horoscope_general_dict, seedlist, q)
print("Signatures computed.")

# Find similar items using the LSH function

similar_items_lsh = lsh(full_signatures, b, jaccard_threshold=threshold, seed=seed_lsh)
# Out:
# Signatures computed.

# %%
similar_items_lsh_highest_value = max(similar_items_lsh.items(), key=lambda x: x[1])
print("Highest similarity pair:")
print(f"ID1: {similar_items_lsh_highest_value[0][0]}, ID2: {similar_items_lsh_highest_value[0][1]}, Similarità: {similar_items_lsh_highest_value[1]:.2f}")
print(f"Text1: {horoscope_general_dict[similar_items_lsh_highest_value[0][0]]}")
print(f"Text2: {horoscope_general_dict[similar_items_lsh_highest_value[0][1]]}")
# Out:
# Highest similarity pair:
# ID1: 11100, ID2: 11147, Similarità: 1.00
# Text1: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.
# Text2: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.

# %%
similar_items_lsh_q_3 = similar_items_lsh

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# First histogram: regular y-scale
ax[0].hist(similar_items_lsh_q_3.values(), bins=100, edgecolor='black')
ax[0].set_title('Histogram of Similarity Scores (Shingle Size = 3)')
ax[0].set_xlabel('Similarity Score')
ax[0].set_ylabel('Frequency')

# Second histogram: log y-scale
ax[1].hist(similar_items_lsh_q_3.values(), bins=100, edgecolor='black')
ax[1].set_title('Histogram of Similarity Scores (Shingle Size = 3)')
ax[1].set_xlabel('Similarity Score')
ax[1].set_ylabel('Log(Frequency)')
ax[1].set_yscale('log')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## size of shingles = 4

# %%
# Parameters

q = 4   # size of the shingle (in words)                   
                            
r = 3      # rows per band                   
                           
k = 120                     # number of hash functions
                            
b = k // r                  # number of bands 
                            
threshold = -0.1            # minimum similarity threshold 
                            
seedlist = list(range(k))   # list of seeds for the hash functions 
                            
seed_lsh = 42               # seed for hashing the blocks 
                            
# Compute MinHash signatures on all documents
full_signatures = signature(horoscope_general_dict, seedlist, q)
print("Signatures computed.")

# Find similar items using the LSH function

similar_items_lsh = lsh(full_signatures, b, jaccard_threshold=threshold, seed=seed_lsh)
# Out:
# Signatures computed.

# %%
similar_items_lsh_highest_value = max(similar_items_lsh.items(), key=lambda x: x[1])
print("Highest similarity pair:")
print(f"ID1: {similar_items_lsh_highest_value[0][0]}, ID2: {similar_items_lsh_highest_value[0][1]}, Similarità: {similar_items_lsh_highest_value[1]:.2f}")
print(f"Text1: {horoscope_general_dict[similar_items_lsh_highest_value[0][0]]}")
print(f"Text2: {horoscope_general_dict[similar_items_lsh_highest_value[0][1]]}")
# Out:
# Highest similarity pair:
# ID1: 11100, ID2: 11147, Similarità: 1.00
# Text1: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.
# Text2: This is the right moment to extricate yourself from relationships that have seen their day, Libra. This won't be easy, but you must. In your professional and private lives, you're too hesitant to get out of distasteful situations or obligations. You're afraid of hurting people or making them mad. But in the end, you're hurting yourself. Give more weight to your own needs and follow your own path.

# %%
similar_items_lsh_q_4 = similar_items_lsh

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# First histogram: regular y-scale
ax[0].hist(similar_items_lsh_q_4.values(), bins=100, edgecolor='black')
ax[0].set_title('Histogram of Similarity Scores (Shingle Size = 4)')
ax[0].set_xlabel('Similarity Score')
ax[0].set_ylabel('Frequency')

# Second histogram: log y-scale
ax[1].hist(similar_items_lsh_q_4.values(), bins=100, edgecolor='black')
ax[1].set_title('Histogram of Similarity Scores (Shingle Size = 4)')
ax[1].set_xlabel('Similarity Score')
ax[1].set_ylabel('Log(Frequency)')
ax[1].set_yscale('log')

plt.tight_layout()
plt.show()
